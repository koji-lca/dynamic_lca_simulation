# %% [markdown]
# <a href="https://colab.research.google.com/github/koji-lca/dynamic_lca_simulation/blob/main/API%E3%81%AB%E3%81%A4%E3%81%84%E3%81%A6%EF%BC%BF%E6%A1%91%E5%8E%9F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

# 東京の緯度経度
lat, lon = 35.6895, 139.6917
#⃣キーは不要
url = f"https://api.open-meteo.com/v1/forecast?latitude={lat}&longitude={lon}&hourly=temperature_2m"

response = requests.get(url)
data = response.json()

# JSON → DataFrame
df = pd.DataFrame({
    "time": data["hourly"]["time"],
    "temp": data["hourly"]["temperature_2m"]
})

df["time"] = pd.to_datetime(df["time"])
df.head()
# Out:
#                  time  temp
# 0 2026-06-24 00:00:00  20.4
# 1 2026-06-24 01:00:00  21.9
# 2 2026-06-24 02:00:00  23.3
# 3 2026-06-24 03:00:00  24.4
# 4 2026-06-24 04:00:00  25.1

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,4))
plt.plot(df["time"], df["temp"], marker="o")
plt.title("Tokyo Temperature (Hourly)")
plt.xlabel("Time")
plt.ylabel("Temperature (°C)")
plt.grid(True)
plt.show()

# %% [markdown]
# ```markdown
# ## GitHubへのアップロード手順
# ```

# %%
# Gitの設定（ユーザー名とメールアドレス）
# !git config --global user.email "your-email@example.com"
# !git config --global user.name "Your Name"

# 認証情報の入力（トークンを使用）
import getpass
user = "YOUR_GITHUB_USERNAME"
repository = "YOUR_REPOSITORY_NAME"
password = getpass.getpass('GitHub Personal Access Token: ')

# リポジトリの初期化とコミット
# !git init
# !git add .
# !git commit -m "Initial commit from Google Colab"

# リモートリポジトリの設定とプッシュ
remote_url = f"https://{user}:{password}@github.com/{user}/{repository}.git"
# !git remote add origin {remote_url}
# !git branch -M main
# !git push -u origin main
